# %% [markdown]
# # Automated ML from Azure

# %% [markdown]
# ## Using the online interface

# %% [markdown]
# Azure accepts data with or without column headers
#
# Here we use the same heart disease dataset as used with the other auto ML tools in this project
#
# We use the breast cancer dataset wtih twice as many rows as was required by Google-AutoML
#
# There is no automatic stopping criteria, you have to wait for the entire process to finish or for the time limit to be reached
#
# The time limit was set to 1 hour

# %% [markdown]
# ### Screen shots

# %% [markdown]
# #### Data Preview

# %%
from IPython.display import Image
Image(filename='images/az5.png')

# %% [markdown]
# #### Configs

# %%
from IPython.display import Image
Image(filename='images/az2.png')

# %%
from IPython.display import Image
Image(filename='images/az4.png')

# %% [markdown]
# #### Results

# %%
from IPython.display import Image
Image(filename='images/az1.png')

# %% [markdown]
# #### Explanations

# %%
from IPython.display import Image
Image(filename='images/az3.png')

# %% [markdown]
# ## Via notebook commands

# %% [markdown]
# #### The following is still a WIP - connecting to AZ ML from a remote notebook

# %% [markdown]
# ## Accuracy
#
# #### Hard-code accuracy for now until we get the remote connection working

# %%
import json
with open('../dominostats.json', 'w') as f:
    f.write(json.dumps( {"HD_ACC": .997, "BC_ACC": .871}))
